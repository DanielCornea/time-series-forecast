# %% [markdown]
# # Computing F factor for selecting companies

# %%
# imports 
import pandas as pd 
import yfinance as yf

# %%
df = pd.read_csv('piotroski.csv')

# %%
df.head()
# Out:
#   Unnamed: 0 company       assets    revenues  net_cash_flow  long_debt_term  \
# 0        MMM     MMM  44659000000  4582000000   7.070000e+09    1.751800e+10
# 1        AOS     AOS   3058000000   370000000   4.562000e+08    2.772000e+08
# 2        ABT     ABT  67887000000  3687000000   6.136000e+09    1.666100e+10
# 3       ABBV    ABBV  89115000000  7882000000   1.332400e+10    1.759700e+10
# 4       ABMD    ABMD   1216462000   203009000   3.149200e+08             NaN
#
#    current_liabilities  current_assets  number_of_shares          cogs  \
# 0         7.020000e+08    1.297100e+10      5.758000e+08  7.400000e+07
# 1         6.460000e+07    1.500400e+09      2.605990e+07  1.812000e+09
# 2         1.237000e+09    1.566700e+10      1.756470e+09  1.323100e+10
# 3         1.183200e+10    4.951900e+10      1.475084e+09  7.439000e+09
# 4         7.510700e+07    6.358630e+08      4.512473e+07  1.513050e+08
#
#    op_income  prev_assets  prev_revenues  prev_net_cash_flow  \
# ...

# %%
df = df.drop(columns = 'Unnamed: 0')

# %%
df.head()
# Out:
#   company       assets    revenues  net_cash_flow  long_debt_term  \
# 0     MMM  44659000000  4582000000   7.070000e+09    1.751800e+10
# 1     AOS   3058000000   370000000   4.562000e+08    2.772000e+08
# 2     ABT  67887000000  3687000000   6.136000e+09    1.666100e+10
# 3    ABBV  89115000000  7882000000   1.332400e+10    1.759700e+10
# 4    ABMD   1216462000   203009000   3.149200e+08             NaN
#
#    current_liabilities  current_assets  number_of_shares          cogs  \
# 0         7.020000e+08    1.297100e+10      5.758000e+08  7.400000e+07
# 1         6.460000e+07    1.500400e+09      2.605990e+07  1.812000e+09
# 2         1.237000e+09    1.566700e+10      1.756470e+09  1.323100e+10
# 3         1.183200e+10    4.951900e+10      1.475084e+09  7.439000e+09
# 4         7.510700e+07    6.358630e+08      4.512473e+07  1.513050e+08
#
#    op_income  prev_assets  prev_revenues  prev_net_cash_flow  \
# 0      66740  36500000000     5363000000          6439000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   company                   366 non-null    object
#  1   assets                    366 non-null    int64
#  2   revenues                  366 non-null    int64
#  3   net_cash_flow             366 non-null    float64
#  4   long_debt_term            205 non-null    float64
#  5   current_liabilities       339 non-null    float64
#  6   current_assets            309 non-null    float64
#  7   number_of_shares          366 non-null    float64
#  8   cogs                      217 non-null    float64
#  9   op_income                 366 non-null    int64
#  10  prev_assets               366 non-null    int64
#  11  prev_revenues             366 non-null    int64
#  12  prev_net_cash_flow        366 non-null    int64
# ...

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 0 to 362
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   company                   120 non-null    object
#  1   assets                    120 non-null    int64
#  2   revenues                  120 non-null    int64
#  3   net_cash_flow             120 non-null    float64
#  4   long_debt_term            120 non-null    float64
#  5   current_liabilities       120 non-null    float64
#  6   current_assets            120 non-null    float64
#  7   number_of_shares          120 non-null    float64
#  8   cogs                      120 non-null    float64
#  9   op_income                 120 non-null    int64
#  10  prev_assets               120 non-null    int64
#  11  prev_revenues             120 non-null    int64
#  12  prev_net_cash_flow        120 non-null    int64
# ...
